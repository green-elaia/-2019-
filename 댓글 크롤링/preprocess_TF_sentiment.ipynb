# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Requirement already satisfied: JPype1>=0.5.7 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.6.3)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.16.3)

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !ls "/gdrive/My Drive/Colab Notebooks/graduation_paper"
# Out:
# pp_comment.py  second_model.h5	    sentimentAnalysis.py  word_comment
# pp_final       selected_words.json  TF_keyword_url

# %%
# !cd "/gdrive/My Drive/Colab Notebooks/graduation_paper"

# %%
# !pwd
# Out:
# /content

# %%
from konlpy.tag import Okt
from tensorflow.keras import models
import csv
import json
import numpy as np

rowNum = 0
preprocess_data = []
totalRow = 0
pp_comment = []
keyword_comment = []

# %%
csvList = [
    
    "pp_final_1_1",
    "pp_final_2_2_5_6",
    "pp_final_3_3_4",
    "pp_final_4",
    "pp_final_5",
    "pp_final_6",
    "pp_final_7",
    "pp_final_8"    
]
##     "url_comment_time_rank_channelName_1_10_0_12653",
## "url_comment_time_rank_channelName_11_19_12654_23266"]
## "url_comment_time_rank_channelName_20_49_23236_33999",
## "url_comment_time_rank_channelName_20_49_2_34000_39000"]
## "url_comment_time_rank_channelName_20_49_3_39000_41999",
## "url_comment_time_rank_channelName_20_49_3_second_42000_43999"]
##"url_comment_time_rank_channelName_20_49_44000_47793",
##"url_comment_time_rank_channelName_50_74_final5_57611_57999",
##"url_comment_time_rank_channelName_50_74_second_58002_61000",
## "url_comment_time_rank_channelName_50_74_2_61002_63999",
## "url_comment_time_rank_channelName_50_74_2_second_64000_66000"]
##"url_comment_time_rank_channelName_50_74_2_third_66000_68325"]
##"url_comment_time_rank_channelName_75_100_68325_81623_END" ]


# ## "url_comment_time_rank_channelName_50_74"
# "url_comment_time_rank_channelName_50_74_final2",
# "url_comment_time_rank_channelName_50_74_final3",
# "url_comment_time_rank_channelName_50_74_final4"
# ]

# %%
keyword_list = ['페이스북',
 '애니메이션',
 '카카오스토리' ]
#  '터닝메카드',
#  '인스타그램',
#  '홈페이지',
#  '구독하기',
#  '재생목록',
#  '꼬마버스',
#  '파워레인저',
#  '미니특공대',
#  '인기동요',
#  '서프라이즈',
#  '로보카폴리',
#  '트레인포스',
#  '다이노포스',
#  '액체괴물',
#  '놀이시간',
#  '교육시간',
#  '슈퍼윙스',
#  '유아교육',
#  '스페이스',
#  '영어동요',
#  '마리디아',
#  '보드게임',
#  '인기동화',
#  '체험시간',
#  '트랜스포머',
#  '블레이드',
#  '미끄럼틀',
#  '장난감놀이',
#  '다이노코어',
#  '색칠놀이',
#  '스마트폰',
#  '캐리앤송',
#  '베이블레이드',
#  '누리과정',
#  '신비아파트',
#  '최강전사',
#  '안드로이드',
#  '깨비키즈',
#  '공룡메카드',
#  '공룡탐험',
#  '색깔놀이',
#  '아이엠스타',
#  '토이튜브',
#  '칠교놀이',
#  '웹사이트',
#  '동요앨범',
#  '낱말카드',
#  '영어그림사전',
#  '과학도감',
#  '꼬마버스타',
#  '아이스크림',
#  '하나누나',
#  '생활습관',
#  '구출작전',
#  '대형마트',
#  '캐리앤북스',
#  '무한도전',
#  '장난감친구',
#  '드리프트',
#  '라임튜브',
#  '키즈카페',
#  '토이스페이스',
#  '아티스트',
#  '캐리앤플레이',
#  '특공트랜스',
#  '소피루비',
#  '병원놀이',
#  '쥬라기월드',
#  '장난감애니메이션',
#  '토이팩토리',
#  '마인크래프트',
#  '토이스페이스장난감공간',
#  '야외촬영',
#  '페파피그',
#  '라이트닝',
#  '메가비스트',
#  '동요동화',
#  '동화이야기',
#  '우주여행',
#  '키즈스타',
#  '젤리괴물',
#  '아기인형',
#  '크리스마스',
#  '미니피겨',
#  '공룡싸움',
#  '스토리채널',
#  '테마극장',
#  '베이비버스',
#  '변신로봇',
#  '대문밖장난감',
#  '율동동요',
#  '바다탐험대',
#  '숫자놀이',
#  '포켓몬스터',
#  '인형놀이',
#  '동물동요',
#  '라임캐스트',
#  '엔터테인먼트',
#  '라임파워',
#  '공룡동요',
#  '마이리틀포니',
#  '돼지해적',
#  '파워레인',
#  '상상놀이터',
#  '겨울왕국',
#  '웹드라마',
#  '사우루스',
#  '백설공주',
#  '남녀노소',
#  '인기동영상',
#  '슈퍼영웅',
#  '사랑전달하기',
#  '꿀잼동영상',
#  '상상이야기',
#  '테마파크',
#  '밀착중계',
#  '플레이모빌',
#  '스타그램',
#  '메이크업',
#  '아일랜드',
#  '슈퍼대시',
#  '요리놀이',
#  '만화영화',
#  '추천영상',
#  '게임소개',
#  '치과체험',
#  '자이언트',
#  '옵티머스',
#  '프로그램',
#  '공룡마을',
#  '자연과학',
#  '연속보기',
#  '성장단계별',
#  '지능발달',
#  '소통의사',
#  '예술감각',
#  '환경보호',
#  '유아동요',
#  '키키묘묘',
#  '스타워즈',
#  '생활습관동',
#  '헬리콥터',
#  '액세서리',
#  '상상더하기',
#  '생활안전동요',
#  '시크릿쥬쥬',
#  '종이종이',
#  '구독버튼',
#  '가면라이더',
#  '초등학교',
#  '일상이야기',
#  '라임이의',
#  '국어버전',
#  '전세계어린이',
#  '요괴메달',
#  '터닝메카드시리즈',
#  '캐리앤프렌즈',
#  '토이마트',
#  '플레이트',
#  '이야기구성',
#  '주방놀이',
#  '장난감이야기',
#  '놀이공원',
#  '패티렐라',
#  '꼬꼬스토이',
#  '멸종동물',
#  '교육채널',
#  '유튜브주소',
#  '고스트볼',
#  '최강탑플레이트',
#  '인기영상',
#  '키즈토이',
#  '헬로카봇',
#  '공룡월드',
#  '토이박스',
#  '퍼즐등등',
#  '어드벤처',
#  '다이노마스터',
#  '영어공부',
#  '좌충우돌',
#  '레인보우',
#  '에피소드',
#  '제이제이',
#  '구조본부',
#  '카드소개',
#  '로봇트레인',
#  '할아버지',
#  '인어공주',
#  '티라노사우',
#  '개구쟁이',
#  '놀이동산',
#  '꼬마캐리',
#  '색칠공부',
#  '프리파라',
#  '업그레이드',
#  '진찰송과',
#  '마스코트',
#  '할로윈특집',
#  '일상영상',
#  '악당출현',
#  '미니피규',
#  '요괴메카드',
#  '필수어플',
#  '스톱모션',
#  '공식채널',
#  '어린이집',
#  '대교어린이',
#  '북스토어',
#  '숨바꼭질',
#  '하나언니',
#  '라이센스',
#  '미미월드',
#  '모래놀이',
#  '소꿉놀이',
#  '미니피규어',
#  '긴급출동센터',
#  '리틀미미',
#  '맥스터핀스',
#  '파워캐치',
#  '모모토이즈',
#  '고고다이노',
#  '직업놀이',
#  '바비인형',
#  '안전수칙',
#  '다이아티비',
#  '일상생활',
#  '다이노튜너',
#  '문의메일',
#  '주입식학습',
#  '문제해결능력',
#  '리원파파',
#  '공룡백과',
#  '네트워크',
#  '꼬마캐빈',
#  '공포특집',
#  '상어가족',
#  '슈퍼히어로',
#  '무시무시',
#  '하우스만들기',
#  '미미인형',
#  '재치만점',
#  '괴짜발명소녀',
#  '오퍼레이터',
#  '환상적인',
#  '구조과정',
#  '아이언맨',
#  '피규어들',
#  '목욕놀이',
#  '비밀친구',
#  '율동교실',
#  '삼지애니메이션',
#  '메카다이노',
#  '라이센스표기',
#  '래빗미디어',
#  '동요부르기',
#  '세계공룡싸움',
#  '인형드라마',
#  '아르바이트',
#  '기상천외',
#  '마이크로',
#  '의사놀이',
#  '과학호기심',
#  '엑티비티',
#  '리틀미미인형',
#  '체험놀이등',
#  '도미노피자',
#  '놀이기구',
#  '사용연령',
#  '직업동요',
#  '생활동화',
#  '엔진포스',
#  '지오메카',
#  '전래동요',
#  '변신자동차',
#  '브라키오',
#  '요구르트',
#  '포크레인',
#  '변신합체',
#  '메가블럭',
#  '시사상식',
#  '아르바이트생',
#  '만들기놀이',
#  '어린이채널',
#  '실험놀이',
#  '분장놀이',
#  '참여방법',
#  '안전교육동요',
#  '뮤직비디오',
#  '감성교육',
#  '추리이야기',
#  '패러디하기',
#  '오프닝부르기',
#  '만화주제가',
#  '스튜디오',
#  '태교음악',
#  '스프라임',
#  '유아성장단계별',
#  '지식영역',
#  '예의범절',
#  '지능계발',
#  '영아기초',
#  '명절동화',
#  '프테라노돈',
#  '워터파크',
#  '인기동요모음',
#  '아기상어',
#  '드라이버',
#  '플토이박스',
#  '학교이야기',
#  '펜타스톰',
#  '발레리나',
#  '포핀쿠킨',
#  '교통안전이야기',
#  '초등학생',
#  '그림그리기',
#  '트레일러',
#  '말레피센트',
#  '영상보기',
#  '미니언즈',
#  '아이디어',
#  '안전교육',
#  '천진난만',
#  '오토바이',
#  '증강현실',
#  '전래동화',
#  '시리즈통합',
#  '사랑이야기',
#  '제조업체',
#  '다이아몬드',
#  '감사드립',
#  '다크에너지',
#  '플레이세트',
#  '다이노셀',
#  '디즈니애니메이션',
#  '인터렉티브',
#  '인형옷만들기',
#  '프린세스',
#  '수입자명',
#  '문어마녀',
#  '토이스토리',
#  '브루미즈',
#  '캡틴포스',
#  '아렌델성',
#  '인형드레스',
#  '가족이야기'

# %%
okt = Okt()
with open('/gdrive/My Drive/Colab Notebooks/graduation_paper/selected_words.json', encoding = 'UTF-8') as f:
        selected_words = json.load(f)
model = models.load_model('/gdrive/My Drive/Colab Notebooks/graduation_paper/second_model.h5')


def tokenize(doc):
    return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]

def term_frequency(doc):
    return [doc.count(word) for word in selected_words]

def predict_sentiment(review):
    token = tokenize(review)
    tf = term_frequency(token)
    data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
    score = float(model.predict(data))
    if(score > 0.5):
        return 1
    else:
        return 0
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def open_pp_csv():
  global pp_comment
  
  for csvName in csvList:
    with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/pp_final/" + csvName + ".csv", 'r', encoding = 'cp949') as p_csv:
        csv_data = csv.reader(p_csv)
        for row in csv_data:
          pp_comment.append(row)

# %%
open_pp_csv()

# %%
len(pp_comment)
# Out:
# 8377734

# %%
def preprocess_keyword_csv(keywordName):
    global keyword_comment
    keyword_comment = []
    length = 0
    
    with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/TF_keyword_url/" + keywordName + ".csv", 'r', encoding = 'cp949') as p_csv:
        length = len(list(csv.reader(p_csv)))

    with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/TF_keyword_url/" + keywordName + ".csv", 'r', encoding = 'cp949') as p_csv:
        print("yeah")
        keyword_data = csv.reader(p_csv)
        print("leng : ", length)
        i = 0

        for row in keyword_data:
          url = row[0]
          flag = False
          print(keywordName, " : ", i, " / ", length)
          i += 1
          
          for pp_data in pp_comment:
            if url in pp_data[0]:
              keyword_comment.append([pp_data[0],pp_data[1], pp_data[2],pp_data[3], pp_data[4], predict_sentiment(pp_data[3])])
              #before_url = pp_data[0]
              flag = True
              continue
            if flag and url not in pp_data[0]:
              break

# %%
def write_csv(csvName):
#     with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/" + "pp_" + csvName +".csv", "w", encoding = 'cp949', newline = '') as p_csv:
    with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/word_comment/" + csvName +".csv", "w", encoding = 'cp949', newline = '') as p_csv:
        writer = csv.writer(p_csv, delimiter = ',')
        for row in keyword_comment:
            writer.writerow(row)
        print("complete")

# %%
# keyword_list = []
# with open("/gdrive/My Drive/Colab Notebooks/graduation_paper/pp_final/keyword_collection.csv", 'r', encoding = 'cp949') as p_csv:
#     csv_data = csv.reader(p_csv)
#     for row in csv_data:
#       keyword_list.append(row)

# %%
len(keyword_list)
# Out:
# 3

# %%
global keyword_list 
global rowNum
rowNum = 0
for keyword_name in keyword_list:
    print("Number : ", rowNum, " keyword : ", keyword_name)
    rowNum += 1
    preprocess_keyword_csv(keyword_name)
    write_csv(keyword_name)
# Out:
# 3305  /  4153
# 3306  /  4153
# 3307  /  4153
# 3308  /  4153
# 3309  /  4153
# 3310  /  4153
# 3311  /  4153
# 3312  /  4153
# 3313  /  4153
# 3314  /  4153
# 3315  /  4153
# 3316  /  4153
# 3317  /  4153
# 3318  /  4153
# 3319  /  4153
# 3320  /  4153
# 3321  /  4153
# 3322  /  4153
# 3323  /  4153
# 3324  /  4153
# 3325  /  4153
# 3326  /  4153
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-07a1db871268> in <module>()
#       5     print("Number : ", rowNum, " keyword : ", keyword_name)
#       6     rowNum += 1
# ----> 7     preprocess_keyword_csv(keyword_name)
#       8     write_csv(keyword_name)
#
# <ipython-input-19-3b7f2dd7bff0> in preprocess_keyword_csv(keywordName)
#      21           for pp_data in pp_comment:
#      22             if url in pp_data[0]:
# ---> 23               keyword_comment.append([pp_data[0],pp_data[1], pp_data[2],pp_data[3], pp_data[4], predict_sentiment(pp_data[3])])
#      24               #before_url = pp_data[0]
#      25               flag = True
#
# <ipython-input-5-9e1a3318f611> in predict_sentiment(review)
#      12
#      13 def predict_sentiment(review):
# ---> 14     token = tokenize(review)
#      15     tf = term_frequency(token)
#      16     data = np.expand_dims(np.asarray(tf).astype('float32'), axis=0)
#
# <ipython-input-5-9e1a3318f611> in tokenize(doc)
#       6
#       7 def tokenize(doc):
# ----> 8     return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
#       9
#      10 def term_frequency(doc):
#
# /usr/local/lib/python3.6/dist-packages/konlpy/tag/_okt.py in pos(self, phrase, norm, stem, join)
#      61                     phrase,
#      62                     jpype.java.lang.Boolean(norm),
# ---> 63                     jpype.java.lang.Boolean(stem)).toArray()
#      64         if join:
#      65             return [t for t in tokens]
#
# /usr/local/lib/python3.6/dist-packages/jpype/_jclass.py in _getClassFor(javaClass)
#      76
#      77
# ---> 78 def _getClassFor(javaClass):
#      79     name = javaClass.getName()
#      80     if name in _CLASSES:
#
# KeyboardInterrupt:
